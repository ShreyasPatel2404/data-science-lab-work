# %%
import pandas as pd

data = pd.read_csv("./Dataset2.csv")
data
# Out:
#    Outlook Temp Wind  Humidity  Class
# 0        R    H    F         1      0
# 1        R    H    T         2      0
# 2        O    H    F         1      1
# 3        R    M    F         1      1
# 4        S    C    F         1      1
# 5        O    C    T         0      0
# 6        O    C    T         1      1
# 7        R    M    F         1      0
# 8        O    C    F         0      1
# 9        S    M    F         2      1
# 10       R    C    T         2      0
# 11       O    M    T         0      1
# 12       O    H    F         1      1
# 13       S    M    T         1      0

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

data["Outlook"] = le.fit_transform(data["Outlook"])
data["Temp"] = le.fit_transform(data["Temp"])
data["Wind"] = le.fit_transform(data["Wind"])

data
# Out:
#     Outlook  Temp  Wind  Humidity  Class
# 0         1     1     0         1      0
# 1         1     1     1         2      0
# 2         0     1     0         1      1
# 3         1     2     0         1      1
# 4         2     0     0         1      1
# 5         0     0     1         0      0
# 6         0     0     1         1      1
# 7         1     2     0         1      0
# 8         0     0     0         0      1
# 9         2     2     0         2      1
# 10        1     0     1         2      0
# 11        0     2     1         0      1
# 12        0     1     0         1      1
# 13        2     2     1         1      0

# %%
X = data.iloc[:, :4]
Y = data.iloc[:, 4:]

from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=.1)

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree

model = DecisionTreeClassifier(criterion="gini")

model.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = model.predict(X_test)

# %%
Y_test
# Out:
#     Class
# 12      1
# 0       0

# %%
import matplotlib.pyplot as plt

plt.figure(
  figsize=(30,10)
)

plot_tree(model)
# Out:
# [Text(0.5, 0.9, 'x[2] <= 0.5\ngini = 0.486\nsamples = 12\nvalue = [5, 7]'),
#  Text(0.2, 0.7, 'x[1] <= 1.5\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.35, 0.8, 'True  '),
#  Text(0.1, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.3, 0.5, 'x[3] <= 1.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.2, 0.3, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.4, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8, 0.7, 'x[0] <= 0.5\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.65, 0.8, '  False'),
#  Text(0.7, 0.5, 'x[1] <= 1.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.6, 0.3, 'x[3] <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.5, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]')]

# %%
model2 = DecisionTreeClassifier(criterion="entropy")
model2.fit(X_train, Y_train)
model2.predict(X_test)

plt.figure(
  figsize=(30,10)
)

plot_tree(model2)
# Out:
# [Text(0.5, 0.9, 'x[2] <= 0.5\nentropy = 0.98\nsamples = 12\nvalue = [5, 7]'),
#  Text(0.2, 0.7, 'x[1] <= 1.5\nentropy = 0.65\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.35, 0.8, 'True  '),
#  Text(0.1, 0.5, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.3, 0.5, 'x[3] <= 1.5\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.2, 0.3, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.4, 0.3, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8, 0.7, 'x[0] <= 0.5\nentropy = 0.918\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.65, 0.8, '  False'),
#  Text(0.7, 0.5, 'x[1] <= 1.0\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.6, 0.3, 'x[3] <= 0.5\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.5, 0.1, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7, 0.1, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8, 0.3, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9, 0.5, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]')]

# %%
model3 = DecisionTreeClassifier(criterion="log_loss")
model3.fit(X_train, Y_train)
model3.predict(X_test)


plt.figure(
  figsize=(30,10)
)

plot_tree(model3)
# Out:
# [Text(0.5, 0.9, 'x[2] <= 0.5\nlog_loss = 0.98\nsamples = 12\nvalue = [5, 7]'),
#  Text(0.2, 0.7, 'x[1] <= 1.5\nlog_loss = 0.65\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.35, 0.8, 'True  '),
#  Text(0.1, 0.5, 'log_loss = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.3, 0.5, 'x[0] <= 1.5\nlog_loss = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.2, 0.3, 'log_loss = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.4, 0.3, 'log_loss = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8, 0.7, 'x[0] <= 0.5\nlog_loss = 0.918\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.65, 0.8, '  False'),
#  Text(0.7, 0.5, 'x[1] <= 1.0\nlog_loss = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.6, 0.3, 'x[3] <= 0.5\nlog_loss = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.5, 0.1, 'log_loss = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7, 0.1, 'log_loss = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8, 0.3, 'log_loss = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9, 0.5, 'log_loss = 0.0\nsamples = 3\nvalue = [3, 0]')]

# %%
model.predict([[2,0,1,2]])
# Out:
# c:\Users\devan\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0], dtype=int64)

# %%
print(model.max_depth)
# Out:
# None

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score
print(accuracy_score(Y_test, y_pred), precision_score(Y_test, y_pred), recall_score(Y_test, y_pred))
# Out:
# 0.5 0.5 1.0

# %%
model4 = DecisionTreeClassifier(criterion="gini", max_depth=2)

model4.fit(X_train, Y_train)

y_pred = model4.predict(X_test)

print(accuracy_score(Y_test, y_pred), recall_score(Y_test, y_pred), precision_score(Y_test, y_pred))
# Out:
# 0.5 1.0 0.5
